# %% [markdown]
# 1. https://apps.marincounty.org/TaxBillOnline/?PropertyId=11217306&__ncforminfo=41lsqeI2Aiy2chb-b2Jg6Uwm-yo2S_GamBPZnrDednu1aIwmzWenA2p0lClfnI9QIvT66uxfM62nvwK7Vpf55juNEQpfLcGwmRpAfwZ4WbE%3D
#
# 2. https://apps.marincounty.org/TaxBillOnline/Bill?BillNumber=24-1096268

# %%
import os
import re
import gzip
import csv

import geopandas as gpd
import requests
from pyproj import Transformer

# ——— Configuration ———
GEOJSON_PATH = r'C:\Users\Dewank Mahajan\Desktop\DKM Business\LowPropTax\AccessorOffice\Marin\Parcels.geojson'
SCRAPE_DIR   = r'C:\Users\Dewank Mahajan\Desktop\DKM Business\LowPropTax\AccessorOffice\Marin\Dir'
OUTPUT_CSV   = r'C:\Users\Dewank Mahajan\Desktop\DKM Business\LowPropTax\AccessorOffice\Marin\output_tax.csv'

os.makedirs(SCRAPE_DIR, exist_ok=True)

# ——— Regexes & Transformer ———
BILL_NUMBER_REGEX    = re.compile(r'BillNumber=([\d-]+)')
FORMINFO_REGEX       = re.compile(r'name="__ncforminfo"\s+value="([^"]+)"')
AMOUNT_REGEX         = re.compile(r'Total Amount Due:\s+<span class="i16">\$([\d,\.]+)')
transformer          = Transformer.from_crs(2227, 4326, always_xy=True)

# ——— Session with browser‑like headers ———
session = requests.Session()
session.headers.update({
    'User-Agent':      'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept':          'text/html,application/xhtml+xml',
    'Referer':         'https://apps.marincounty.org/TaxBillOnline/'
})

def fetch_and_save_bill(apn, out_path):
    """Fetch the bill HTML, gzip-save it, and return a status code."""
    # 1) main page
    r1 = session.get(f'https://apps.marincounty.org/TaxBillOnline/?PropertyId={apn}')
    if r1.status_code != 200:
        return 'FetchError'
    m_bill = BILL_NUMBER_REGEX.search(r1.text)
    if not m_bill:
        return 'NoBillNumber'
    bill_number = m_bill.group(1)

    m_form = FORMINFO_REGEX.search(r1.text)
    if not m_form:
        return 'NoFormInfo'
    forminfo = m_form.group(1)

    # 2) actual bill page
    r2 = session.get(
        f'https://apps.marincounty.org/TaxBillOnline/Bill'
        f'?BillNumber={bill_number}&__ncforminfo={forminfo}'
    )
    if r2.status_code != 200:
        return 'FetchError'

    with gzip.open(out_path, 'wt', encoding='utf-8') as gz:
        gz.write(r2.text)
    return 'Fetched'

def extract_tax_from_gz(path):
    """Open gzipped HTML and pull out the tax amount."""
    with gzip.open(path, 'rt', encoding='utf-8') as gz:
        html = gz.read()
    m = AMOUNT_REGEX.search(html)
    if not m:
        return None
    return float(m.group(1).replace(',', ''))

# ——— Load GeoJSON ———
print("Loading GeoJSON…")
gdf = gpd.read_file(GEOJSON_PATH)
print(f"  → {len(gdf)} parcels loaded.")

# ——— Prepare CSV ———
with open(OUTPUT_CSV, 'w', newline='', encoding='utf-8') as f_out:
    fieldnames = ['address', 'apn', 'longitude', 'latitude', 'tax', 'county', 'zone', 'comment']
    writer = csv.DictWriter(f_out, fieldnames=fieldnames)
    writer.writeheader()

    # ——— Iterate parcels ———
    for idx, row in gdf.iterrows():
        apn = row['Prop_ID']
        print(f"[{idx+1}/{len(gdf)}] APN {apn}")

        # centroid + transform
        centroid = row.geometry.centroid
        lon, lat = transformer.transform(centroid.x, centroid.y)

        # address + commercial flag
        address = row.get('AssessorSi') or ''
        if 'UseCdDesc' in row and row['UseCdDesc'] and 'Commercial' in row['UseCdDesc']:
            address += ' (Commercial)'

        # decide whether to fetch or reuse
        gz_path = os.path.join(SCRAPE_DIR, f"{apn}.html.gz")
        if not os.path.exists(gz_path):
            status = fetch_and_save_bill(apn, gz_path)
            if status != 'Fetched':
                tax = ''
                print(f"   → {status}")
            else:
                tax_val = extract_tax_from_gz(gz_path)
                if tax_val is None:
                    tax = ''
                    status = 'ParseError'
                    print("   → ParseError")
                else:
                    tax = f"{tax_val:.2f}"
                    print(f"   → tax = {tax}")
        else:
            status = 'Cached'
            tax_val = extract_tax_from_gz(gz_path)
            if tax_val is None:
                tax = ''
                status = 'ParseError'
                print("   → Cached but ParseError")
            else:
                tax = f"{tax_val:.2f}"
                print(f"   → Cached, tax = {tax}")

        # write row with comment
        writer.writerow({
            'address': address,
            'apn': apn,
            'longitude': lon,
            'latitude': lat,
            'tax': tax,
            'county': 'MN',
            'zone': '',
            'comment': status
        })

print("Done! CSV written to:", OUTPUT_CSV)
# Out:
# Loading GeoJSON…
#   → 96285 parcels loaded.
# [1/96285] APN 024-261-01
#    → NoBillNumber
# [2/96285] APN 109-270-12
#    → NoBillNumber
# [3/96285] APN 132-163-18
#    → NoBillNumber
# [4/96285] APN 160-833-14
#    → NoBillNumber
# [5/96285] APN 058-390-16
#    → NoBillNumber
# [6/96285] APN 165-220-16
#    → NoBillNumber
# [7/96285] APN 160-832-05
#    → NoBillNumber
# [8/96285] APN 179-270-15
#    → NoBillNumber
# [9/96285] APN 175-451-26
#    → NoBillNumber
# [10/96285] APN 058-171-85
#    → NoBillNumber
# [11/96285] APN 114-171-05
#    → NoBillNumber
# [12/96285] APN 022-631-01
#    → NoBillNumber
# [13/96285] APN 191-071-14
#    → NoBillNumber
# [14/96285] APN 028-154-11
#    → NoBillNumber
# [15/96285] APN 025-012-15
#    → NoBillNumber
# [16/96285] APN 039-101-31
#    → NoBillNumber
# [17/96285] APN 006-119-11
#    → NoBillNumber
# [18/96285] APN 005-211-49
#    → NoBillNumber
# [19/96285] APN 170-130-26
#    → NoBillNumber
# [20/96285] APN 028-222-84
#    → NoBillNumber
# [21/96285] APN 165-220-05
#    → NoBillNumber
# [22/96285] APN 168-222-06
#    → NoBillNumber
# [23/96285] APN 024-076-05
#    → NoBillNumber
# [24/96285] APN 168-270-16
#    → NoBillNumber
# [25/96285] APN 025-034-12
#    → NoBillNumber
# [26/96285] APN 073-091-17
#    → NoBillNumber
# [27/96285] APN 184-010-31
#    → NoBillNumber
# [28/96285] APN 174-190-09
#    → NoBillNumber
# [29/96285] APN 199-191-13
#    → NoBillNumber
# [30/96285] APN 160-150-64
#    → NoBillNumber
# [31/96285] APN 025-034-10
#    → NoBillNumber
# [32/96285] APN 006-083-42
#    → NoBillNumber
# [33/96285] APN 195-222-20
#    → NoBillNumber
# [34/96285] APN 030-032-23
#    → NoBillNumber
# [35/96285] APN 014-011-01
#    → NoBillNumber
# [36/96285] APN 165-220-03
#    → NoBillNumber
# [37/96285] APN 165-220-04
#    → NoBillNumber
# [38/96285] APN 170-120-33
#    → NoBillNumber
# [39/96285] APN 185-071-11
#    → NoBillNumber
# [40/96285] APN 157-180-27
#    → NoBillNumber
# [41/96285] APN 059-042-16
#    → NoBillNumber
# [42/96285] APN 064-132-19
#    → NoBillNumber
# [43/96285] APN 029-052-15
#    → NoBillNumber
# [44/96285] APN 165-220-02
#    → NoBillNumber
# [45/96285] APN 160-840-34
#    → NoBillNumber
# [46/96285] APN 901-010-34
#    → NoBillNumber
# [47/96285] APN 170-150-11
#    → NoBillNumber
# [48/96285] APN 074-192-23
#    → NoBillNumber
# [49/96285] APN 060-191-06
#    → NoBillNumber
# [50/96285] APN 027-151-01
#    → NoBillNumber
# [51/96285] APN 160-790-20
#    → NoBillNumber
# [52/96285] APN 022-631-43
#    → NoBillNumber
# [53/96285] APN 038-372-34
#    → NoBillNumber
# [54/96285] APN 143-471-02
#    → NoBillNumber
# [55/96285] APN 058-390-44
#    → NoBillNumber
# [56/96285] APN 049-063-23
#    → NoBillNumber
# [57/96285] APN 193-133-34
#    → NoBillNumber
# [58/96285] APN 058-312-11
#    → NoBillNumber
# [59/96285] APN 022-390-18
#    → NoBillNumber
# [60/96285] APN 010-221-33
#    → NoBillNumber
# [61/96285] APN 038-410-11
#    → NoBillNumber
# [62/96285] APN 193-103-11
#    → NoBillNumber
# [63/96285] APN 070-133-08
#    → NoBillNumber
# [64/96285] APN 060-195-03
#    → NoBillNumber
# [65/96285] APN 059-012-02
#    → NoBillNumber
# [66/96285] APN 075-151-67
#    → NoBillNumber
# [67/96285] APN 075-091-19
#    → NoBillNumber
# [68/96285] APN 197-033-01
#    → NoBillNumber
# [69/96285] APN 900-120-24
#    → NoBillNumber
# [70/96285] APN 150-263-08
#    → NoBillNumber
# [71/96285] APN 900-081-59
#    → NoBillNumber
# [72/96285] APN 193-103-10
#    → NoBillNumber
# [73/96285] APN 193-133-07
#    → NoBillNumber
# [74/96285] APN 060-195-18
#    → NoBillNumber
# [75/96285] APN 027-242-05
#    → NoBillNumber
# [76/96285] APN 060-291-05
#    → NoBillNumber
# [77/96285] APN 027-066-22
#    → NoBillNumber
# [78/96285] APN 073-232-44
#    → NoBillNumber
# [79/96285] APN 017-450-01
#    → NoBillNumber
# [80/96285] APN 009-081-27
#    → NoBillNumber
# [81/96285] APN 030-420-65
#    → NoBillNumber
# [82/96285] APN 058-370-29
#    → NoBillNumber
# [83/96285] APN 152-401-05
#    → NoBillNumber
# [84/96285] APN 195-101-16
#    → NoBillNumber
# [85/96285] APN 022-670-14
#    → NoBillNumber
# [86/96285] APN 029-103-60
#    → NoBillNumber
# [87/96285] APN 059-142-11
#    → NoBillNumber
# [88/96285] APN 059-051-17
#    → NoBillNumber
# [89/96285] APN 060-155-23
#    → NoBillNumber
# [90/96285] APN 121-160-40
#    → NoBillNumber
# [91/96285] APN 071-011-03
#    → NoBillNumber
# [92/96285] APN 051-271-16
#    → NoBillNumber
# [93/96285] APN 197-120-03
#    → NoBillNumber
# [94/96285] APN 172-343-11
#    → NoBillNumber
# [95/96285] APN 048-031-38
#    → NoBillNumber
# [96/96285] APN 901-020-33
#    → NoBillNumber
# [97/96285] APN 177-071-13
#    → NoBillNumber
# [98/96285] APN 180-380-29
#    → NoBillNumber
# [99/96285] APN 011-031-23
#    → NoBillNumber
# [100/96285] APN 039-251-07
#    → NoBillNumber
# [101/96285] APN 011-253-03
#    → NoBillNumber
# [102/96285] APN 034-370-13
#    → NoBillNumber
# [103/96285] APN 160-680-05
#    → NoBillNumber
# [104/96285] APN 051-261-19
#    → NoBillNumber
# [105/96285] APN 065-224-08
#    → NoBillNumber
# [106/96285] APN 060-161-16
#    → NoBillNumber
# [107/96285] APN 200-303-03
#    → NoBillNumber
# [108/96285] APN 022-471-24
#    → NoBillNumber
# [109/96285] APN 176-112-02
#    → NoBillNumber
# [110/96285] APN 172-251-15
#    → NoBillNumber
# [111/96285] APN 010-101-61
#    → NoBillNumber
# [112/96285] APN 058-351-08
#    → NoBillNumber
# [113/96285] APN 022-221-16
#    → NoBillNumber
# [114/96285] APN 114-011-15
#    → NoBillNumber
# [115/96285] APN 058-321-03
#    → NoBillNumber
# [116/96285] APN 060-163-04
#    → NoBillNumber
# [117/96285] APN 003-043-15
#    → NoBillNumber
# [118/96285] APN 007-024-14
#    → NoBillNumber
# [119/96285] APN 901-040-05
#    → NoBillNumber
# [120/96285] APN 175-370-39
#    → NoBillNumber
# [121/96285] APN 010-241-74
#    → NoBillNumber
# [122/96285] APN 192-112-03
#    → NoBillNumber
# [123/96285] APN 164-014-10
#    → NoBillNumber
# [124/96285] APN 034-072-28
#    → NoBillNumber
# [125/96285] APN 074-062-19
#    → NoBillNumber
# [126/96285] APN 011-011-36
#    → NoBillNumber
# [127/96285] APN 146-040-43
#    → NoBillNumber
# [128/96285] APN 140-400-37
#    → NoBillNumber
# [129/96285] APN 030-062-39
#    → NoBillNumber
# [130/96285] APN 018-113-22
#    → NoBillNumber
# [131/96285] APN 058-141-05
#    → NoBillNumber
# [132/96285] APN 010-185-24
#    → NoBillNumber
# [133/96285] APN 160-105-14
#    → NoBillNumber
# [134/96285] APN 075-151-68
#    → NoBillNumber
# [135/96285] APN 058-282-15
#    → NoBillNumber
# [136/96285] APN 157-540-16
#    → NoBillNumber
# [137/96285] APN 001-222-01
#    → NoBillNumber
# [138/96285] APN 060-191-01
#    → NoBillNumber
# [139/96285] APN 176-043-20
#    → NoBillNumber
# [140/96285] APN 009-251-10
#    → NoBillNumber
# [141/96285] APN 049-044-17
#    → NoBillNumber
# [142/96285] APN 009-251-25
#    → NoBillNumber
# [143/96285] APN 157-810-20
#    → NoBillNumber
# [144/96285] APN 160-541-46
#    → NoBillNumber
# [145/96285] APN 010-052-10
#    → NoBillNumber
# [146/96285] APN 065-162-12
#    → NoBillNumber
# [147/96285] APN 022-741-03
#    → NoBillNumber
# [148/96285] APN 022-741-01
#    → NoBillNumber
# [149/96285] APN 022-741-42
#    → NoBillNumber
# [150/96285] APN 022-741-06
#    → NoBillNumber
# [151/96285] APN 030-192-08
#    → NoBillNumber
# [152/96285] APN 022-741-02
#    → NoBillNumber
# [153/96285] APN 022-741-07
#    → NoBillNumber
# [154/96285] APN 022-741-08
#    → NoBillNumber
# [155/96285] APN 028-055-31
#    → NoBillNumber
# [156/96285] APN 172-262-14
#    → NoBillNumber
# [157/96285] APN 064-211-37
#    → NoBillNumber
# [158/96285] APN 034-152-11
#    → NoBillNumber
# [159/96285] APN 100-251-14
#    → NoBillNumber
# [160/96285] APN 112-291-09
#    → NoBillNumber
# [161/96285] APN 112-174-09
#    → NoBillNumber
# [162/96285] APN 195-310-07
#    → NoBillNumber
# [163/96285] APN 065-400-02
#    → NoBillNumber
# [164/96285] APN 112-173-05
#    → NoBillNumber
# [165/96285] APN 114-120-72
#    → NoBillNumber
# [166/96285] APN 065-211-33
#    → NoBillNumber
# [167/96285] APN 065-211-32
#    → NoBillNumber
# [168/96285] APN 112-243-02
#    → NoBillNumber
# [169/96285] APN 195-080-35
#    → NoBillNumber
# [170/96285] APN 028-056-10
#    → NoBillNumber
# [171/96285] APN 026-290-03
#    → NoBillNumber
# [172/96285] APN 029-114-24
#    → NoBillNumber
# [173/96285] APN 065-400-04
#    → NoBillNumber
# [174/96285] APN 065-400-01
#    → NoBillNumber
# [175/96285] APN 114-100-44
#    → NoBillNumber
# [176/96285] APN 065-400-05
#    → NoBillNumber
# [177/96285] APN 070-302-22
#    → NoBillNumber
# [178/96285] APN 195-090-30
#    → NoBillNumber
# [179/96285] APN 195-340-20
#    → NoBillNumber
# [180/96285] APN 074-031-61
#    → NoBillNumber
# [181/96285] APN 022-212-28
#    → NoBillNumber
# [182/96285] APN 112-173-06
#    → NoBillNumber
# [183/96285] APN 195-300-13
#    → NoBillNumber
# [184/96285] APN 021-095-06
#    → NoBillNumber
# [185/96285] APN 191-211-13
#    → NoBillNumber
# [186/96285] APN 028-012-15
#    → NoBillNumber
# [187/96285] APN 100-311-13
#    → NoBillNumber
# [188/96285] APN 064-204-35
#    → NoBillNumber
# [189/96285] APN 064-151-38
#    → NoBillNumber
# [190/96285] APN 073-101-14
#    → NoBillNumber
# [191/96285] APN 073-041-27
#    → NoBillNumber
# [192/96285] APN 119-091-17
#    → NoBillNumber
# [193/96285] APN 114-350-03
#    → NoBillNumber
# [194/96285] APN 043-132-10
#    → NoBillNumber
# [195/96285] APN 075-051-02
#    → NoBillNumber
# [196/96285] APN 195-193-20
#    → NoBillNumber
# [197/96285] APN 114-330-14
#    → NoBillNumber
# [198/96285] APN 059-101-02
#    → NoBillNumber
# [199/96285] APN 059-012-18
#    → NoBillNumber
# [200/96285] APN 029-185-05
#    → NoBillNumber
# [201/96285] APN 059-132-03
#    → NoBillNumber
# [202/96285] APN 114-271-19
#    → NoBillNumber
# [203/96285] APN 100-151-26
#    → NoBillNumber
# [204/96285] APN 100-341-17
#    → NoBillNumber
# [205/96285] APN 169-221-23
#    → NoBillNumber
# [206/96285] APN 100-321-04
#    → NoBillNumber
# [207/96285] APN 058-081-06
#    → NoBillNumber
# [208/96285] APN 100-132-04
#    → NoBillNumber
# [209/96285] APN 100-171-04
#    → NoBillNumber
# [210/96285] APN 055-021-09
#    → NoBillNumber
# [211/96285] APN 030-281-33
#    → NoBillNumber
# [212/96285] APN 034-303-06
#    → NoBillNumber
# [213/96285] APN 025-012-09
#    → NoBillNumber
# [214/96285] APN 060-051-37
#    → NoBillNumber
# [215/96285] APN 168-141-12
#    → NoBillNumber
# [216/96285] APN 058-031-12
#    → NoBillNumber
# [217/96285] APN 121-070-11
#    → NoBillNumber
# [218/96285] APN 055-121-10
#    → NoBillNumber
# [219/96285] APN 168-191-07
#    → NoBillNumber
# [220/96285] APN 100-261-25
#    → NoBillNumber
# [221/96285] APN 002-161-16
#    → NoBillNumber
# [222/96285] APN 065-222-13
#    → NoBillNumber
# [223/96285] APN 100-151-27
#    → NoBillNumber
# [224/96285] APN 112-041-10
#    → NoBillNumber
# [225/96285] APN 003-101-22
#    → NoBillNumber
# [226/96285] APN 002-192-20
#    → NoBillNumber
# [227/96285] APN 028-016-03
#    → NoBillNumber
# [228/96285] APN 047-112-61
#    → NoBillNumber
# [229/96285] APN 100-323-01
#    → NoBillNumber
# [230/96285] APN 006-192-26
#    → NoBillNumber
# [231/96285] APN 005-142-24
#    → NoBillNumber
# [232/96285] APN 007-251-11
#    → NoBillNumber
# [233/96285] APN 188-140-58
#    → NoBillNumber
# [234/96285] APN 046-173-05
#    → NoBillNumber
# [235/96285] APN 006-191-50
#    → NoBillNumber
# [236/96285] APN 100-341-18
#    → NoBillNumber
# [237/96285] APN 005-183-16
#    → NoBillNumber
# [238/96285] APN 071-052-32
#    → NoBillNumber
# [239/96285] APN 020-201-21
#    → NoBillNumber
# [240/96285] APN 030-193-06
#    → NoBillNumber
# [241/96285] APN 028-024-14
#    → NoBillNumber
# [242/96285] APN 005-252-02
#    → NoBillNumber
# [243/96285] APN 021-085-45
#    → NoBillNumber
# [244/96285] APN 051-111-43
#    → NoBillNumber
# [245/96285] APN 192-151-01
#    → NoBillNumber
# [246/96285] APN 010-282-12
#    → NoBillNumber
# [247/96285] APN 043-450-05
#    → NoBillNumber
# [248/96285] APN 025-084-17
#    → NoBillNumber
# [249/96285] APN 901-040-12
#    → NoBillNumber
# [250/96285] APN 175-432-21
#    → NoBillNumber
# [251/96285] APN 065-222-05
#    → NoBillNumber
# [252/96285] APN 155-470-10
#    → NoBillNumber
# [253/96285] APN 155-210-17
#    → NoBillNumber
# [254/96285] APN 009-061-11
#    → NoBillNumber
# [255/96285] APN 175-432-17
#    → NoBillNumber
# [256/96285] APN 015-011-07
#    → NoBillNumber
# [257/96285] APN 046-212-23
#    → NoBillNumber
# [258/96285] APN 180-380-40
#    → NoBillNumber
# [259/96285] APN 064-134-03
#    → NoBillNumber
# [260/96285] APN 175-431-82
#    → NoBillNumber
# [261/96285] APN 003-142-23
#    → NoBillNumber
# [262/96285] APN 050-211-02
#    → NoBillNumber
# [263/96285] APN 026-191-22
#    → NoBillNumber
# [264/96285] APN 001-142-01
#    → NoBillNumber
# [265/96285] APN 114-330-05
#    → NoBillNumber
# [266/96285] APN 049-182-42
#    → NoBillNumber
# [267/96285] APN 192-081-14
#    → NoBillNumber
# [268/96285] APN 174-081-10
#    → NoBillNumber
# [269/96285] APN 065-202-52
#    → NoBillNumber
# [270/96285] APN 175-380-42
#    → NoBillNumber
# [271/96285] APN 065-112-14
#    → NoBillNumber
# [272/96285] APN 065-202-51
#    → NoBillNumber
# [273/96285] APN 045-113-46
#    → NoBillNumber
# [274/96285] APN 175-411-49
#    → NoBillNumber
# [275/96285] APN 175-411-15
#    → NoBillNumber
# [276/96285] APN 001-150-37
#    → NoBillNumber
# [277/96285] APN 049-182-43
#    → NoBillNumber
# [278/96285] APN 065-121-05
#    → NoBillNumber
# [279/96285] APN 075-290-03
#    → NoBillNumber
# [280/96285] APN 014-022-25
#    → NoBillNumber
# [281/96285] APN 191-201-04
#    → NoBillNumber
# [282/96285] APN 060-155-13
#    → NoBillNumber
# [283/96285] APN 028-213-14
#    → NoBillNumber
# [284/96285] APN 028-241-10
#    → NoBillNumber
# [285/96285] APN 024-122-12
#    → NoBillNumber
# [286/96285] APN 012-014-21
#    → NoBillNumber
# [287/96285] APN 020-223-09
#    → NoBillNumber
# [288/96285] APN 045-131-23
#    → NoBillNumber
# [289/96285] APN 047-221-16
#    → NoBillNumber
# [290/96285] APN 007-121-80
#    → NoBillNumber
# [291/96285] APN 011-271-01
#    → NoBillNumber
# [292/96285] APN 164-471-19
#    → NoBillNumber
# [293/96285] APN 011-205-10
#    → NoBillNumber
# [294/96285] APN 175-432-84
#    → NoBillNumber
# [295/96285] APN 011-261-01
#    → NoBillNumber
# [296/96285] APN 175-370-01
#    → NoBillNumber
# [297/96285] APN 015-041-21
#    → NoBillNumber
# [298/96285] APN 016-032-06
#    → NoBillNumber
# [299/96285] APN 011-142-14
#    → NoBillNumber
# [300/96285] APN 166-330-02
#    → NoBillNumber
# [301/96285] APN 100-261-09
#    → NoBillNumber
# [302/96285] APN 009-241-82
#    → NoBillNumber
# [303/96285] APN 166-340-08
#    → NoBillNumber
# [304/96285] APN 166-340-07
#    → NoBillNumber
# [305/96285] APN 017-440-02
#    → NoBillNumber
# [306/96285] APN 155-375-09
#    → NoBillNumber
# [307/96285] APN 001-021-11
#    → NoBillNumber
# [308/96285] APN 165-171-30
#    → NoBillNumber
# [309/96285] APN 011-224-15
#    → NoBillNumber
# [310/96285] APN 185-271-12
#    → NoBillNumber
# [311/96285] APN 008-072-06
#    → NoBillNumber
# [312/96285] APN 184-220-15
#    → NoBillNumber
# [313/96285] APN 021-085-50
#    → NoBillNumber
# [314/96285] APN 011-205-12
#    → NoBillNumber
# [315/96285] APN 052-092-07
#    → NoBillNumber
# [316/96285] APN 180-011-17
#    → NoBillNumber
# [317/96285] APN 034-122-35
#    → NoBillNumber
# [318/96285] APN 010-291-58
#    → NoBillNumber
# [319/96285] APN 010-273-09
#    → NoBillNumber
# [320/96285] APN 014-152-29
#    → NoBillNumber
# [321/96285] APN 175-412-64
#    → NoBillNumber
# [322/96285] APN 025-065-01
#    → NoBillNumber
# [323/96285] APN 030-052-09
#    → NoBillNumber
# [324/96285] APN 012-181-29
#    → NoBillNumber
# [325/96285] APN 012-182-12
#    → NoBillNumber
# [326/96285] APN 197-110-03
#    → NoBillNumber
# [327/96285] APN 058-011-13
#    → NoBillNumber
# [328/96285] APN 008-091-12
#    → NoBillNumber
# [329/96285] APN 058-283-06
#    → NoBillNumber
# [330/96285] APN 152-291-46
#    → NoBillNumber
# [331/96285] APN 125-600-36
#    → NoBillNumber
# [332/96285] APN 151-132-01
#    → NoBillNumber
# [333/96285] APN 152-241-64
#    → NoBillNumber
# [334/96285] APN 141-082-05
#    → NoBillNumber
# [335/96285] APN 178-028-08
#    → NoBillNumber
# [336/96285] APN 010-291-39
#    → NoBillNumber
# [337/96285] APN 014-181-06
#    → NoBillNumber
# [338/96285] APN 185-255-08
#    → NoBillNumber
# [339/96285] APN 180-074-32
#    → NoBillNumber
# [340/96285] APN 039-271-11
#    → NoBillNumber
# [341/96285] APN 011-261-31
#    → NoBillNumber
# [342/96285] APN 178-072-06
#    → NoBillNumber
# [343/96285] APN 065-191-09
#    → NoBillNumber
# [344/96285] APN 175-181-06
#    → NoBillNumber
# [345/96285] APN 065-142-35
#    → NoBillNumber
# [346/96285] APN 011-231-16
#    → NoBillNumber
# [347/96285] APN 901-010-30
#    → NoBillNumber
# [348/96285] APN 155-376-52
#    → NoBillNumber
# [349/96285] APN 015-041-06
#    → NoBillNumber
# [350/96285] APN 011-084-29
#    → NoBillNumber
# [351/96285] APN 015-041-22
#    → NoBillNumber
# [352/96285] APN 169-231-29
#    → NoBillNumber
# [353/96285] APN 012-076-02
#    → NoBillNumber
# [354/96285] APN 180-501-07
#    → NoBillNumber
# [355/96285] APN 005-082-09
#    → NoBillNumber
# [356/96285] APN 059-400-10
#    → NoBillNumber
# [357/96285] APN 043-131-10
#    → NoBillNumber
# [358/96285] APN 033-092-08
#    → NoBillNumber
# [359/96285] APN 180-442-07
#    → NoBillNumber
# [360/96285] APN 028-082-38
#    → NoBillNumber
# [361/96285] APN 160-541-50
#    → NoBillNumber
# [362/96285] APN 140-400-14
#    → NoBillNumber
# [363/96285] APN 152-241-82
#    → NoBillNumber
# [364/96285] APN 072-061-08
#    → NoBillNumber
# [365/96285] APN 157-900-04
#    → NoBillNumber
# [366/96285] APN 157-930-05
#    → NoBillNumber
# [367/96285] APN 177-134-15
#    → NoBillNumber
# [368/96285] APN 175-283-09
#    → NoBillNumber
# [369/96285] APN 150-222-08
#    → NoBillNumber
# [370/96285] APN 157-790-24
#    → NoBillNumber
# [371/96285] APN 160-601-25
#    → NoBillNumber
# [372/96285] APN 143-434-05
#    → NoBillNumber
# [373/96285] APN 150-293-01
#    → NoBillNumber
# [374/96285] APN 033-031-02
#    → NoBillNumber
# [375/96285] APN 152-381-31
#    → NoBillNumber
# [376/96285] APN 132-223-07
#    → NoBillNumber
# [377/96285] APN 151-082-16
#    → NoBillNumber
# [378/96285] APN 125-171-13
#    → NoBillNumber
# [379/96285] APN 177-092-02
#    → NoBillNumber
# [380/96285] APN 141-032-26
#    → NoBillNumber
# [381/96285] APN 152-291-45
#    → NoBillNumber
# [382/96285] APN 132-352-16
#    → NoBillNumber
# [383/96285] APN 146-180-46
#    → NoBillNumber
# [384/96285] APN 140-041-26
#    → NoBillNumber
# [385/96285] APN 124-092-03
#    → NoBillNumber
# [386/96285] APN 160-173-26
#    → NoBillNumber
# [387/96285] APN 143-670-04
#    → NoBillNumber
# [388/96285] APN 143-670-05
#    → NoBillNumber
# [389/96285] APN 157-144-10
#    → NoBillNumber
# [390/96285] APN 160-760-41
#    → NoBillNumber
# [391/96285] APN 146-161-05
#    → NoBillNumber
# [392/96285] APN 125-150-23
#    → NoBillNumber
# [393/96285] APN 157-102-18
#    → NoBillNumber
# [394/96285] APN 052-363-05
#    → NoBillNumber
# [395/96285] APN 052-380-05
#    → NoBillNumber
# [396/96285] APN 104-220-02
#    → NoBillNumber
# [397/96285] APN 151-051-33
#    → NoBillNumber
# [398/96285] APN 058-390-11
#    → NoBillNumber
# [399/96285] APN 052-480-37
#    → NoBillNumber
# [400/96285] APN 006-144-03
#    → NoBillNumber
# [401/96285] APN 065-340-02
#    → NoBillNumber
# [402/96285] APN 022-741-37
#    → NoBillNumber
# [403/96285] APN 010-052-12
#    → NoBillNumber
# [404/96285] APN 022-741-25
#    → NoBillNumber
# [405/96285] APN 168-290-05
#    → NoBillNumber
# [406/96285] APN 140-460-96
#    → NoBillNumber
# [407/96285] APN 157-770-38
#    → NoBillNumber
# [408/96285] APN 141-142-34
#    → NoBillNumber
# [409/96285] APN 143-052-11
#    → NoBillNumber
# [410/96285] APN 125-150-19
#    → NoBillNumber
# [411/96285] APN 157-061-29
#    → NoBillNumber
# [412/96285] APN 141-081-56
#    → NoBillNumber
# [413/96285] APN 175-060-52
#    → NoBillNumber
# [414/96285] APN 052-480-32
#    → NoBillNumber
# [415/96285] APN 114-120-73
#    → NoBillNumber
# [416/96285] APN 010-251-14
#    → NoBillNumber
# [417/96285] APN 010-074-16
#    → NoBillNumber
# [418/96285] APN 022-741-31
#    → NoBillNumber
# [419/96285] APN 050-061-05
#    → NoBillNumber
# [420/96285] APN 064-360-76
#    → NoBillNumber
# [421/96285] APN 022-741-23
#    → NoBillNumber
# [422/96285] APN 001-022-01
#    → NoBillNumber
# [423/96285] APN 028-214-09
#    → NoBillNumber
# [424/96285] APN 034-122-15
#    → NoBillNumber
# [425/96285] APN 007-131-53
#    → NoBillNumber
# [426/96285] APN 043-440-07
#    → NoBillNumber
# [427/96285] APN 060-103-41
#    → NoBillNumber
# [428/96285] APN 006-262-24
#    → NoBillNumber
# [429/96285] APN 002-112-13
#    → NoBillNumber
# [430/96285] APN 001-062-12
#    → NoBillNumber
# [431/96285] APN 051-095-09
#    → NoBillNumber
# [432/96285] APN 046-173-02
#    → NoBillNumber
# [433/96285] APN 011-224-02
#    → NoBillNumber
# [434/96285] APN 155-050-52
#    → NoBillNumber
# [435/96285] APN 055-082-14
#    → NoBillNumber
# [436/96285] APN 012-132-51
#    → NoBillNumber
# [437/96285] APN 064-301-02
#    → NoBillNumber
# [438/96285] APN 155-050-50
#    → NoBillNumber
# [439/96285] APN 009-320-40
#    → NoBillNumber
# [440/96285] APN 030-043-37
#    → NoBillNumber
# [441/96285] APN 160-492-78
#    → NoBillNumber
# [442/96285] APN 009-132-37
#    → NoBillNumber
# [443/96285] APN 152-393-09
#    → NoBillNumber
# [444/96285] APN 146-441-12
#    → NoBillNumber
# [445/96285] APN 160-402-42
#    → NoBillNumber
# [446/96285] APN 152-350-26
#    → NoBillNumber
# [447/96285] APN 132-165-06
#    → NoBillNumber
# [448/96285] APN 152-060-38
#    → NoBillNumber
# [449/96285] APN 141-281-11
#    → NoBillNumber
# [450/96285] APN 152-232-78
#    → NoBillNumber
# [451/96285] APN 150-561-21
#    → NoBillNumber
# [452/96285] APN 143-110-57
#    → NoBillNumber
# [453/96285] APN 125-500-22
#    → NoBillNumber
# [454/96285] APN 175-060-53
#    → NoBillNumber
# [455/96285] APN 175-060-51
#    → NoBillNumber
# [456/96285] APN 195-320-08
#    → NoBillNumber
# [457/96285] APN 058-370-39
#    → NoBillNumber
# [458/96285] APN 022-540-07
#    → NoBillNumber
# [459/96285] APN 190-052-42
#    → NoBillNumber
# [460/96285] APN 195-310-71
#    → NoBillNumber
# [461/96285] APN 006-290-21
#    → NoBillNumber
# [462/96285] APN 064-343-59
#    → NoBillNumber
# [463/96285] APN 006-290-10
#    → NoBillNumber
# [464/96285] APN 029-095-34
#    → NoBillNumber
# [465/96285] APN 125-180-17
#    → NoBillNumber
# [466/96285] APN 065-252-70
#    → NoBillNumber
# [467/96285] APN 157-103-41
#    → NoBillNumber
# [468/96285] APN 124-312-23
#    → NoBillNumber
# [469/96285] APN 022-741-39
#    → NoBillNumber
# [470/96285] APN 153-320-07
#    → NoBillNumber
# [471/96285] APN 152-401-08
#    → NoBillNumber
# [472/96285] APN 125-150-20
#    → NoBillNumber
# [473/96285] APN 157-231-04
#    → NoBillNumber
# [474/96285] APN 160-970-26
#    → NoBillNumber
# [475/96285] APN 030-331-26
#    → NoBillNumber
# [476/96285] APN 175-060-54
#    → NoBillNumber
# [477/96285] APN 125-150-10
#    → NoBillNumber
# [478/96285] APN 006-290-18
#    → NoBillNumber
# [479/96285] APN 006-290-20
#    → NoBillNumber
# [480/96285] APN 059-051-12
#    → NoBillNumber
# [481/96285] APN 010-131-19
#    → NoBillNumber
# [482/96285] APN 065-330-06
#    → NoBillNumber
# [483/96285] APN 022-741-62
#    → NoBillNumber
# [484/96285] APN 022-741-63
#    → NoBillNumber
# [485/96285] APN 022-741-65
#    → NoBillNumber
# [486/96285] APN 022-741-66
#    → NoBillNumber
# [487/96285] APN 022-741-67
#    → NoBillNumber
# [488/96285] APN 022-741-24
#    → NoBillNumber
# [489/96285] APN 022-741-58
#    → NoBillNumber
# [490/96285] APN 022-741-59
#    → NoBillNumber
# [491/96285] APN 022-741-61
#    → NoBillNumber
# [492/96285] APN 022-741-32
#    → NoBillNumber
# [493/96285] APN 022-741-57
#    → NoBillNumber
# [494/96285] APN 022-741-69
#    → NoBillNumber
# [495/96285] APN 022-741-94
#    → NoBillNumber
# [496/96285] APN 022-741-72
#    → NoBillNumber
# [497/96285] APN 155-050-51
#    → NoBillNumber
# [498/96285] APN 058-370-04
#    → NoBillNumber
# [499/96285] APN 022-611-36
#    → NoBillNumber
# [500/96285] APN 022-741-15
#    → NoBillNumber
# [501/96285] APN 022-741-60
#    → NoBillNumber
# [502/96285] APN 022-741-64
#    → NoBillNumber
# [503/96285] APN 022-741-68
#    → NoBillNumber
# [504/96285] APN 022-741-70
#    → NoBillNumber
# [505/96285] APN 065-101-28
#    → NoBillNumber
# [506/96285] APN 065-052-04
#    → NoBillNumber
# [507/96285] APN 065-052-09
#    → NoBillNumber
# [508/96285] APN 065-123-11
#    → NoBillNumber
# [509/96285] APN 064-254-30
#    → NoBillNumber
# [510/96285] APN 018-014-68
#    → NoBillNumber
# [511/96285] APN 018-014-69
#    → NoBillNumber
# [512/96285] APN 065-103-18
#    → NoBillNumber
# [513/96285] APN 065-034-02
#    → NoBillNumber
# [514/96285] APN 065-052-11
#    → NoBillNumber
# [515/96285] APN 065-052-27
#    → NoBillNumber
# [516/96285] APN 112-271-01
#    → NoBillNumber
# [517/96285] APN 038-301-19
#    → NoBillNumber
# [518/96285] APN 034-181-17
#    → NoBillNumber
# [519/96285] APN 114-251-04
#    → NoBillNumber
# [520/96285] APN 065-302-66
#    → NoBillNumber
# [521/96285] APN 114-101-11
#    → NoBillNumber
# [522/96285] APN 172-191-28
#    → NoBillNumber
# [523/96285] APN 172-191-01
#    → NoBillNumber
# [524/96285] APN 114-191-09
#    → NoBillNumber
# [525/96285] APN 034-174-07
#    → NoBillNumber
# [526/96285] APN 114-273-16
#    → NoBillNumber
# [527/96285] APN 114-100-73
#    → NoBillNumber
# [528/96285] APN 065-034-03
#    → NoBillNumber
# [529/96285] APN 034-243-05
#    → NoBillNumber
# [530/96285] APN 034-160-01
#    → NoBillNumber
# [531/96285] APN 119-198-31
#    → NoBillNumber
# [532/96285] APN 172-252-13
#    → NoBillNumber
# [533/96285] APN 119-198-17
#    → NoBillNumber
# [534/96285] APN 119-203-07
#    → NoBillNumber
# [535/96285] APN 038-331-02
#    → NoBillNumber
# [536/96285] APN 170-091-06
#    → NoBillNumber
# [537/96285] APN 058-212-47
#    → NoBillNumber
# [538/96285] APN 195-132-10
#    → NoBillNumber
# [539/96285] APN 114-282-24
#    → NoBillNumber
# [540/96285] APN 114-283-06
#    → NoBillNumber
# [541/96285] APN 064-251-07
#    → NoBillNumber
# [542/96285] APN 112-300-40
#    → NoBillNumber
# [543/96285] APN 195-105-06
#    → NoBillNumber
# [544/96285] APN 112-295-27
#    → NoBillNumber
# [545/96285] APN 112-233-02
#    → NoBillNumber
# [546/96285] APN 034-172-02
#    → NoBillNumber
# [547/96285] APN 034-172-30
#    → NoBillNumber
# [548/96285] APN 034-271-04
#    → NoBillNumber
# [549/96285] APN 034-171-04
#    → NoBillNumber
# [550/96285] APN 034-271-30
#    → NoBillNumber
# [551/96285] APN 112-291-13
#    → NoBillNumber
# [552/96285] APN 034-221-02
#    → NoBillNumber
# [553/96285] APN 112-241-11
#    → NoBillNumber
# [554/96285] APN 109-320-90
#    → NoBillNumber
# [555/96285] APN 112-273-18
#    → NoBillNumber
# [556/96285] APN 034-113-03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 97
#      95 gz_path = os.path.join(SCRAPE_DIR, f"{apn}.html.gz")
#      96 if not os.path.exists(gz_path):
# ---> 97     status = fetch_and_save_bill(apn, gz_path)
#      98     if status != 'Fetched':
#      99         tax = ''
#
# Cell In[10], line 35, in fetch_and_save_bill(apn, out_path)
#      33 """Fetch the bill HTML, gzip-save it, and return a status code."""
#      34 # 1) main page
# ---> 35 r1 = session.get(f'https://apps.marincounty.org/TaxBillOnline/?PropertyId={apn}')
#      36 if r1.status_code != 200:
#      37     return 'FetchError'
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~\anaconda3\Lib\http\client.py:1386, in HTTPConnection.getresponse(self)
#    1384 try:
#    1385     try:
# -> 1386         response.begin()
#    1387     except ConnectionError:
#    1388         self.close()
#
# File ~\anaconda3\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~\anaconda3\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1315, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1311     if flags != 0:
#    1312         raise ValueError(
#    1313           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1314           self.__class__)
# -> 1315     return self.read(nbytes, buffer)
#    1316 else:
#    1317     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
